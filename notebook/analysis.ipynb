# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

with open('../outputs/results.json', 'r') as f:
    res = json.load(f)

print(f"Final Test RMSE: {res['test_rmse']:.4f}")
print(f"Final Test R2: {res['test_r2']:.4f}")
